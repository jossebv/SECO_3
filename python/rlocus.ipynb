# %%
import numpy as np
import matplotlib.pyplot as plt
import control as ctrl

K = 2652.28
p = 64.986

sys = ctrl.TransferFunction([26.52, 2652.28, 265228], [1, 64.986, 0, 0])
ctrl.rlocus(sys, kvect=np.linspace(0, 2, 1000))

# plt.show()
plt.xlim(-150, 150)
plt.ylim(-150, 150)
#plt.savefig("Figuras/rlocus_P-D.png")
plt.show()
